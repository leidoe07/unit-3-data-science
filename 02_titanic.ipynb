# %% [markdown]
# # Titanic Tabulation

# %%
import matplotlib.pyplot as plt

import pandas as pd

# %%
titanic_df = pd.read_csv("titanic_passengers.csv")

# %% [markdown]
# ### What percentage of passengers were 3rd class?

# %%
passenger_class = titanic_df.groupby('Pclass')
passenger_class['Pclass'].value_counts().plot.pie(y='Pclass', figsize=(5, 5))

plt.show()

# %% [markdown]
# ###    Who was the oldest passenger to survive?

# %%
passenger_age = titanic_df.groupby('Age')
titanic_df.hist("Age", figsize=(21,  10))
plt.xlabel('Age')
plt.ylabel('Number of Passengers')
plt.show()

# %% [markdown]
#  ### Did class affect whether or not passenger had a cabin.

# %% [markdown]
# ### What is the survival rates of passengers based on age and gender.

# %% [markdown]
# ###    How many passengers with family member on the titanic had cabin.
